# %% [markdown]
# # Educational Dataset Analysis
#
# This repository contains an analysis of the Educational Dataset of Pakistan. The dataset provides information on various educational indicators and infrastructure in different provinces of Pakistan.
#
# ## Dataset Description
#
# The dataset is in CSV format and consists of 580 rows and 51 columns. Each row represents a specific entry related to educational data, while each column represents a specific attribute or variable. Some of the important columns include:
#
# % Boys Enrolled: The percentage of boys enrolled in schools.
#
# % Complete Primary Schools: The percentage of primary schools that are considered complete.
#
# % Girls Enrolled: The percentage of girls enrolled in schools.
#
# % Primary Schools with single classroom: The percentage of primary schools with only one classroom.
#
# % Primary Schools with single teacher: The percentage of primary schools with only one teacher.
#
# All Four Facilities: The presence of all four facilities (boundary wall, building condition satisfactory, drinking water, and more).
#
# Area (km²): The area in square kilometers.
#
# Terrorist Attacks Affectees: The number of people affected by terrorist attacks.
#
# Toilet: The availability of toilets in schools.
#
# Total number of schools: The total number of schools.
#
#
# ## Analysis
#
# The analysis of the dataset includes exploring the distribution of various variables, identifying patterns, and examining the relationship between different factors. It aims to provide insights into the educational landscape of Pakistan and highlight areas that require attention and improvement.

# %% [markdown]
# # Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Read Dataset

# %%
ed = pd.read_csv("Educational Dataset of Pakistan.csv")

# %%
ed.head()
# Out:
#    % Boys Enrolled  % Complete Primary Schools  % Girls Enrolled  \
# 0              NaN                    0.936599               NaN
# 1              NaN                    0.594203               NaN
# 2              NaN                    0.939068               NaN
# 3              NaN                    0.827225               NaN
# 4              NaN                    0.592348               NaN
#
#    % Primary Schools with single classroom  \
# 0                                 0.034582
# 1                                 0.359903
# 2                                 0.021505
# 3                                 0.041885
# 4                                 0.346966
#
#    % Primary Schools with single teacher  All Four Facilities  \
# 0                               0.028818                  NaN
# 1                               0.045894                  NaN
# 2                               0.039427                  NaN
# 3                               0.130890                  NaN
# 4                               0.060686                  NaN
#
#   Any One Facility Any Three Facilities Any Two Facilities  Area (km²)  ...  \
# 0           16.20%               24.73%             24.95%       768.0  ...
# 1           20.21%               17.38%             15.43%      1516.0  ...
# 2            4.55%               16.31%             20.05%         NaN  ...
# 3           22.44%                7.09%             12.20%       600.0  ...
# 4           23.06%                9.78%             13.60%      2162.0  ...
#
#    Primary Schools with single classroom Primary Schools with single teacher  \
# 0                                   12.0                                10.0
# 1                                  149.0                                19.0
# 2                                    6.0                                11.0
# 3                                    8.0                                25.0
# 4                                  263.0                                46.0
#
#    Province  Retention score  School infrastructure score  \
# 0       AJK             14.8                    24.929178
# 1       AJK             75.2                    28.883827
# 2       AJK              0.0                    22.463768
# 3       AJK              0.0                    13.048128
# 4       AJK             73.2                    20.184453
#
#    Terrorist Attacks Affectees     Toilet Total number of schools  Year  \
# 0                         5379  37.393768                     601  2013
# 1                         5379  20.728929                     595  2013
# 2                         5379  43.840580                     379  2013
# 3                         5379  26.203209                     262  2013
# 4                         5379  14.888011                    1036  2013
#
#   Year on Year Change
# 0                 NaN
# 1            9.704002
# 2          -17.313724
# 3           -4.762458
# 4            8.122142
#
# [5 rows x 52 columns]

# %% [markdown]
# ## Information Of Dataset

# %%
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 580 entries, 0 to 579
# Data columns (total 51 columns):
#  #   Column                                                                                Non-Null Count  Dtype
# ---  ------                                                                                --------------  -----
#  0   % Boys Enrolled                                                                       579 non-null    object
#  1   % Complete Primary Schools                                                            576 non-null    float64
#  2   % Girls Enrolled                                                                      579 non-null    object
#  3   % Primary Schools with single classroom                                               576 non-null    float64
#  4   % Primary Schools with single teacher                                                 576 non-null    float64
#  5   All Four Facilities                                                                   576 non-null    object
#  6   Any One Facility                                                                      576 non-null    object
#  7   Any Three Facilities                                                                  576 non-null    object
#  8   Any Two Facilities                                                                    576 non-null    object
#  9   Area (km²)                                                                            512 non-null    float64
#  10  Bomb Blasts Occurred                                                                  580 non-null    int64
#  11  Boundary wall, Building condition satisfactory, Drinking water and 2 more (clusters)  580 non-null    object
#  12  Boundary wall                                                                         580 non-null    float64
#  13  Building condition satisfactory                                                       580 non-null    float64
#  14  MeasureGroup 1 Measures                                                               580 non-null    float64
#  15  Color By Measure Value                                                                580 non-null    float64
#  16  Show Sheet                                                                            580 non-null    object
#  17  Table of Contents                                                                     580 non-null    object
#  18  Other Factors Measure Value                                                           580 non-null    object
#  19  Analysis Level Selector                                                               580 non-null    object
#  20  Color By Measure Name                                                                 580 non-null    object
#  21  Complete Primary Schools                                                              576 non-null    float64
#  22  Country                                                                               580 non-null    object
#  23  City                                                                                  580 non-null    object
#  24  Drinking water                                                                        580 non-null    float64
#  25  Drone attacks in Pakistan                                                             580 non-null    int64
#  26  Education score                                                                       580 non-null    float64
#  27  Educational Budget Spend of GDP                                                       580 non-null    object
#  28  Electricity                                                                           580 non-null    float64
#  29  Enrolment score                                                                       580 non-null    float64
#  30  Gender parity score                                                                   580 non-null    float64
#  31  Global Terrorism Index - Pakistan                                                     580 non-null    float64
#  32  Learning score                                                                        580 non-null    float64
#  33  MeasureGroup 2 Measures                                                               580 non-null    float64
#  34  No Facility                                                                           576 non-null    object
#  35  Number of Records                                                                     580 non-null    int64
#  36  Number of primary schools as % of total schools                                       580 non-null    float64
#  37  Number of primary schools                                                             580 non-null    int64
#  38  Number of secondary schools as % of total schools                                     580 non-null    float64
#  39  Number of secondary schools                                                           580 non-null    int64
#  40  Pakistan Economic Growth                                                              580 non-null    object
#  41  Population                                                                            512 non-null    float64
#  42  Primary Schools with single classroom                                                 576 non-null    float64
#  43  Primary Schools with single teacher                                                   576 non-null    float64
#  44  Province                                                                              580 non-null    object
#  45  Retention score                                                                       580 non-null    float64
#  46  School infrastructure score                                                           580 non-null    float64
#  47  Terrorist Attacks Affectees                                                           580 non-null    int64
#  48  Toilet                                                                                580 non-null    float64
#  49  Total number of schools                                                               580 non-null    int64
#  50  Year                                                                                  580 non-null    int64
# dtypes: float64(25), int64(8), object(18)
# memory usage: 231.2+ KB

# %%
ed.ndim
# Out:
# 2

# %%
ed.shape
# Out:
# (580, 51)

# %% [markdown]
# ## Null Values in Dataset

# %%
ed.isnull()
# Out:
#      % Boys Enrolled  % Complete Primary Schools  % Girls Enrolled  \
# 0              False                       False             False
# 1              False                       False             False
# 2              False                       False             False
# 3              False                       False             False
# 4              False                       False             False
# ..               ...                         ...               ...
# 575            False                       False             False
# 576            False                       False             False
# 577            False                       False             False
# 578            False                       False             False
# 579            False                       False             False
#
#      % Primary Schools with single classroom  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 575                                    False
# 576                                    False
# 577                                    False
# 578                                    False
# 579                                    False
#
#      % Primary Schools with single teacher  All Four Facilities  \
# 0                                    False                False
# 1                                    False                False
# 2                                    False                False
# 3                                    False                False
# 4                                    False                False
# ..                                     ...                  ...
# 575                                  False                False
# 576                                  False                False
# 577                                  False                False
# 578                                  False                False
# 579                                  False                False
#
#      Any One Facility  Any Three Facilities  Any Two Facilities  Area (km²)  \
# 0               False                 False               False       False
# 1               False                 False               False       False
# 2               False                 False               False        True
# 3               False                 False               False       False
# 4               False                 False               False       False
# ..                ...                   ...                 ...         ...
# 575             False                 False               False       False
# 576             False                 False               False       False
# 577             False                 False               False       False
# 578             False                 False               False       False
# 579             False                 False               False       False
#
#      ...  Population  Primary Schools with single classroom  \
# 0    ...       False                                  False
# 1    ...       False                                  False
# 2    ...        True                                  False
# 3    ...       False                                  False
# 4    ...       False                                  False
# ..   ...         ...                                    ...
# 575  ...       False                                  False
# 576  ...       False                                  False
# 577  ...       False                                  False
# 578  ...       False                                  False
# 579  ...       False                                  False
#
#      Primary Schools with single teacher  Province  Retention score  \
# 0                                  False     False            False
# 1                                  False     False            False
# 2                                  False     False            False
# 3                                  False     False            False
# 4                                  False     False            False
# ..                                   ...       ...              ...
# 575                                False     False            False
# 576                                False     False            False
# 577                                False     False            False
# 578                                False     False            False
# 579                                False     False            False
#
#      School infrastructure score  Terrorist Attacks Affectees  Toilet  \
# 0                          False                        False   False
# 1                          False                        False   False
# 2                          False                        False   False
# 3                          False                        False   False
# 4                          False                        False   False
# ..                           ...                          ...     ...
# 575                        False                        False   False
# 576                        False                        False   False
# 577                        False                        False   False
# 578                        False                        False   False
# 579                        False                        False   False
#
#      Total number of schools   Year
# 0                      False  False
# 1                      False  False
# 2                      False  False
# 3                      False  False
# 4                      False  False
# ..                       ...    ...
# 575                    False  False
# 576                    False  False
# 577                    False  False
# 578                    False  False
# 579                    False  False
#
# [580 rows x 51 columns]

# %% [markdown]
# ## Sum of all Null Values

# %%
ed.isnull().sum(axis = 0)
# Out:
# % Boys Enrolled                                                                          1
# % Complete Primary Schools                                                               4
# % Girls Enrolled                                                                         1
# % Primary Schools with single classroom                                                  4
# % Primary Schools with single teacher                                                    4
# All Four Facilities                                                                      4
# Any One Facility                                                                         4
# Any Three Facilities                                                                     4
# Any Two Facilities                                                                       4
# Area (km²)                                                                              68
# Bomb Blasts Occurred                                                                     0
# Boundary wall, Building condition satisfactory, Drinking water and 2 more (clusters)     0
# Boundary wall                                                                            0
# Building condition satisfactory                                                          0
# MeasureGroup 1 Measures                                                                  0
# Color By Measure Value                                                                   0
# Show Sheet                                                                               0
# Table of Contents                                                                        0
# Other Factors Measure Value                                                              0
# Analysis Level Selector                                                                  0
# Color By Measure Name                                                                    0
# Complete Primary Schools                                                                 4
# Country                                                                                  0
# City                                                                                     0
# Drinking water                                                                           0
# Drone attacks in Pakistan                                                                0
# Education score                                                                          0
# Educational Budget Spend of GDP                                                          0
# Electricity                                                                              0
# Enrolment score                                                                          0
# Gender parity score                                                                      0
# Global Terrorism Index - Pakistan                                                        0
# Learning score                                                                           0
# MeasureGroup 2 Measures                                                                  0
# No Facility                                                                              4
# Number of Records                                                                        0
# Number of primary schools as % of total schools                                          0
# Number of primary schools                                                                0
# Number of secondary schools as % of total schools                                        0
# Number of secondary schools                                                              0
# Pakistan Economic Growth                                                                 0
# Population                                                                              68
# Primary Schools with single classroom                                                    4
# Primary Schools with single teacher                                                      4
# Province                                                                                 0
# Retention score                                                                          0
# School infrastructure score                                                              0
# Terrorist Attacks Affectees                                                              0
# Toilet                                                                                   0
# Total number of schools                                                                  0
# Year                                                                                     0
# dtype: int64

# %% [markdown]
# ## Null Values in Area km²

# %%
ed["Area (km²)"].isnull()
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 575    False
# 576    False
# 577    False
# 578    False
# 579    False
# Name: Area (km²), Length: 580, dtype: bool

# %% [markdown]
# ## Now Find Index oF Area km²

# %%
ed.columns.get_loc("Area (km²)")
# Out:
# 9

# %%
for index, row in ed.iterrows():
    if len(row) >= 10:
        print(row[9])
    else:
        print("Index out of range")
# Out:
# 768.0
# 1516.0
# nan
# 600.0
# 2162.0
# 2310.0
# 2496.0
# nan
# 855.0
# 569.0
# 12510.0
# 3514.0
# 44748.0
# 10160.0
# 12637.0
# 4096.0
# 2445.0
# 3615.0
# 7499.0
# 6622.0
# 22539.0
# 8958.0
# 35380.0
# 3293.0
# 6831.0
# 7610.0
# 15153.0
# 9830.0
# 5896.0
# 5728.0
# 3387.0
# 5797.0
# 16891.0
# 7819.0
# 2653.0
# 0.0
# 7796.0
# 29510.0
# 20297.0
# 1489.0
# nan
# 1227.0
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 6400.0
# 9635.0
# 3800.0
# 15700.0
# 15000.0
# 906.0
# 1967.0
# nan
# 1301.0
# 1865.0
# 996.0
# 14850.0
# 7326.0
# 1597.0
# 1725.0
# 3372.0
# 2545.0
# 7492.0
# 3164.0
# 1582.0
# 952.0
# 4579.0
# 1632.0
# 1748.0
# 1257.0
# 1586.0
# 1543.0
# 5337.0
# 1679.0
# 497.0
# 3699.0
# 6858.0
# 8878.0
# 24830.0
# 8153.0
# 6524.0
# 0.0
# 11922.0
# 5856.0
# 3622.0
# 3192.0
# 2367.0
# 8809.0
# 3587.0
# 4796.0
# 4349.0
# 6511.0
# 1772.0
# 6291.0
# 2778.0
# 2673.0
# 5840.0
# 3720.0
# 8249.0
# 2960.0
# 2337.0
# 3004.0
# 2724.0
# 11880.0
# 12319.0
# 5286.0
# 3201.0
# 5854.0
# 15960.0
# 3016.0
# 3252.0
# 4364.0
# 6726.0
# 19070.0
# 6083.0
# 5519.0
# ..              ...                         ...              ...
# 575          63.98%                    0.214286           36.02%
# 576          73.89%                    0.000000           26.11%
# 577          75.73%                    0.024200           24.27%
# 578          71.06%                    0.018284           28.94%
# 579          62.13%                    0.089423           37.87%
#
#      % Primary Schools with single classroom  \
# 0                                   0.034582
# 1                                   0.359903
# 2                                   0.021505
# 3                                   0.041885
# 4                                   0.346966
# ..                                       ...
# 575                                 0.215633
# 576                                 0.440000
# 577                                 0.417585
# 578                                 0.514768
# 579                                 0.328365
#
#      % Primary Schools with single teacher All Four Facilities  \
# 0                                 0.028818              17.06%
# 1                                 0.045894              15.25%
# 2                                 0.039427               5.35%
# 3                                 0.130890               1.57%
# 4                                 0.060686               7.12%
# ..                                     ...                 ...
# 575                               0.570081              31.77%
# 576                               0.743158              14.16%
# 577                               0.558215               2.10%
# 578                               0.466948               2.71%
# 579                               0.582212              10.56%
#
#     Any One Facility Any Three Facilities Any Two Facilities    Area (km²)  \
# 0             16.20%               24.73%             24.95%         768.0
# 1             20.21%               17.38%             15.43%        1516.0
# 2              4.55%               16.31%             20.05%  Area Unknown
# 3             22.44%                7.09%             12.20%         600.0
# 4             23.06%                9.78%             13.60%        2162.0
# ..               ...                  ...                ...           ...
# 575           12.64%               23.71%             20.58%        5165.0
# 576           22.81%               25.17%             19.08%        2310.0
# 577           15.12%               10.10%             19.79%       19638.0
# 578           22.57%                4.82%             25.48%       19638.0
# 579           22.64%               13.52%             25.20%       17355.0
#
#      ...  Population Primary Schools with single classroom  \
# 0    ...    351415.0                                  12.0
# 1    ...    301633.0                                 149.0
# 2    ...         NaN                                   6.0
# 3    ...    150000.0                                   8.0
# 4    ...    834094.0                                 263.0
# ..   ...         ...                                   ...
# 575  ...    908373.0                                 160.0
# 576  ...    550000.0                                 418.0
# 577  ...    955812.0                                1553.0
# 578  ...    914291.0                                 732.0
# 579  ...   1113194.0                                 683.0
#
#      Primary Schools with single teacher  Province  Retention score  \
# 0                                   10.0       AJK        14.800000
# 1                                   19.0       AJK        75.200000
# 2                                   11.0       AJK         0.000000
# 3                                   25.0       AJK         0.000000
# 4                                   46.0       AJK        73.200000
# ..                                   ...       ...              ...
# 575                                423.0     Sindh        59.000000
# 576                                706.0     Sindh        43.668667
# 577                               2076.0     Sindh        26.000000
# 578                                664.0     Sindh        18.000000
# 579                               1211.0     Sindh        36.000000
#
#      School infrastructure score Terrorist Attacks Affectees     Toilet  \
# 0                      24.929178                        5379  37.393768
# 1                      28.883827                        5379  20.728929
# 2                      22.463768                        5379  43.840580
# 3                      13.048128                        5379  26.203209
# 4                      20.184453                        5379  14.888011
# ..                           ...                         ...        ...
# 575                    55.390836                        1803  62.533693
# 576                    43.010526                        1803  50.947368
# 577                    26.071525                        1803  33.019629
# 578                    19.774965                        1803  35.161744
# 579                    35.730769                        1803  54.615385
#
#     Total number of schools  Year
# 0                       601  2013
# 1                       595  2013
# 2                       379  2013
# 3                       262  2013
# 4                      1036  2013
# ..                      ...   ...
# 575                     831  2016
# 576                    1017  2016
# 577                    4008  2016
# 578                    1515  2016
# 579                    2226  2016
#
# [580 rows x 51 columns]

# %%
ed['Area (km²)']
# Out:
# 0             768.0
# 1            1516.0
# 2      Area Unknown
# 3             600.0
# 4            2162.0
#            ...
# 575          5165.0
# 576          2310.0
# 577         19638.0
# 578         19638.0
# 579         17355.0
# Name: Area (km²), Length: 580, dtype: object

# %% [markdown]
# ## Now Find Index of Population

# %%
ed.columns.get_loc("Population")
# Out:
# 41

# %% [markdown]
# ## Now Convert Null Values of Population into Unknown

# %%
for index, row in ed.iterrows():
    Area = row['Population']
    if pd.isna(Area) or Area == "":
        ed.at[index, 'Population'] = "Unknown"
ed
# Out:
#     % Boys Enrolled  % Complete Primary Schools % Girls Enrolled  \
# 0            54.77%                    0.936599           45.23%
# 1            62.50%                    0.594203           37.50%
# 2            86.63%                    0.939068           13.37%
# 3            60.77%                    0.827225           39.23%
# 4            60.75%                    0.592348           39.25%
# ..              ...                         ...              ...
# 575          63.98%                    0.214286           36.02%
# 576          73.89%                    0.000000           26.11%
# 577          75.73%                    0.024200           24.27%
# 578          71.06%                    0.018284           28.94%
# 579          62.13%                    0.089423           37.87%
#
#      % Primary Schools with single classroom  \
# 0                                   0.034582
# 1                                   0.359903
# 2                                   0.021505
# 3                                   0.041885
# 4                                   0.346966
# ..                                       ...
# 575                                 0.215633
# 576                                 0.440000
# 577                                 0.417585
# 578                                 0.514768
# 579                                 0.328365
#
#      % Primary Schools with single teacher All Four Facilities  \
# 0                                 0.028818              17.06%
# 1                                 0.045894              15.25%
# 2                                 0.039427               5.35%
# 3                                 0.130890               1.57%
# 4                                 0.060686               7.12%
# ..                                     ...                 ...
# 575                               0.570081              31.77%
# 576                               0.743158              14.16%
# 577                               0.558215               2.10%
# 578                               0.466948               2.71%
# 579                               0.582212              10.56%
#
#     Any One Facility Any Three Facilities Any Two Facilities    Area (km²)  \
# 0             16.20%               24.73%             24.95%         768.0
# 1             20.21%               17.38%             15.43%        1516.0
# 2              4.55%               16.31%             20.05%  Area Unknown
# 3             22.44%                7.09%             12.20%         600.0
# 4             23.06%                9.78%             13.60%        2162.0
# ..               ...                  ...                ...           ...
# 575           12.64%               23.71%             20.58%        5165.0
# 576           22.81%               25.17%             19.08%        2310.0
# 577           15.12%               10.10%             19.79%       19638.0
# 578           22.57%                4.82%             25.48%       19638.0
# 579           22.64%               13.52%             25.20%       17355.0
#
#      ...  Population Primary Schools with single classroom  \
# 0    ...    351415.0                                  12.0
# 1    ...    301633.0                                 149.0
# 2    ...     Unknown                                   6.0
# 3    ...    150000.0                                   8.0
# 4    ...    834094.0                                 263.0
# ..   ...         ...                                   ...
# 575  ...    908373.0                                 160.0
# 576  ...    550000.0                                 418.0
# 577  ...    955812.0                                1553.0
# 578  ...    914291.0                                 732.0
# 579  ...   1113194.0                                 683.0
#
#      Primary Schools with single teacher  Province  Retention score  \
# 0                                   10.0       AJK        14.800000
# 1                                   19.0       AJK        75.200000
# 2                                   11.0       AJK         0.000000
# 3                                   25.0       AJK         0.000000
# 4                                   46.0       AJK        73.200000
# ..                                   ...       ...              ...
# 575                                423.0     Sindh        59.000000
# 576                                706.0     Sindh        43.668667
# 577                               2076.0     Sindh        26.000000
# 578                                664.0     Sindh        18.000000
# 579                               1211.0     Sindh        36.000000
#
#      School infrastructure score Terrorist Attacks Affectees     Toilet  \
# 0                      24.929178                        5379  37.393768
# 1                      28.883827                        5379  20.728929
# 2                      22.463768                        5379  43.840580
# 3                      13.048128                        5379  26.203209
# 4                      20.184453                        5379  14.888011
# ..                           ...                         ...        ...
# 575                    55.390836                        1803  62.533693
# 576                    43.010526                        1803  50.947368
# 577                    26.071525                        1803  33.019629
# 578                    19.774965                        1803  35.161744
# 579                    35.730769                        1803  54.615385
#
#     Total number of schools  Year
# 0                       601  2013
# 1                       595  2013
# 2                       379  2013
# 3                       262  2013
# 4                      1036  2013
# ..                      ...   ...
# 575                     831  2016
# 576                    1017  2016
# 577                    4008  2016
# 578                    1515  2016
# 579                    2226  2016
#
# [580 rows x 51 columns]

# %%
ed["Population"]
# Out:
# 0       351415.0
# 1       301633.0
# 2        Unknown
# 3       150000.0
# 4       834094.0
#          ...
# 575     908373.0
# 576     550000.0
# 577     955812.0
# 578     914291.0
# 579    1113194.0
# Name: Population, Length: 580, dtype: object

# %% [markdown]
# # The average enrollment percentage for boys and girls

# %%
ed['% Boys Enrolled'] = pd.to_numeric(ed['% Boys Enrolled'], errors='coerce')
ed['% Girls Enrolled'] = pd.to_numeric(ed['% Girls Enrolled'], errors='coerce')

boys_enrollment_avg = ed['% Boys Enrolled'].mean()
girls_enrollment_avg = ed['% Girls Enrolled'].mean()

print("Average enrollment percentage for boys: ", str(boys_enrollment_avg))
print("Average enrollment percentage for girls: ", str(girls_enrollment_avg))
# Out:
# Average enrollment percentage for boys:  nan
# Average enrollment percentage for girls:  nan

# %% [markdown]
# # Count the number of primary schools with a single classroom

# %%
single_classroom_count = ed['% Primary Schools with single classroom'].sum()
print("Number of primary schools with a single classroom:", single_classroom_count)
# Out:
# Number of primary schools with a single classroom: 77.837307044

# %% [markdown]
# # the percentage of primary schools with all four facilities

# %%
ed['All Four Facilities'] = pd.to_numeric(ed['All Four Facilities'], errors='coerce')
ed['Area (km²)'] = pd.to_numeric(ed['Area (km²)'], errors='coerce')

all_facilities_percentage = (ed['All Four Facilities'] / ed['Area (km²)']) * 100

print("Percentage of primary schools with all four facilities:")
print(all_facilities_percentage)
# Out:
# Percentage of primary schools with all four facilities:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 575   NaN
# 576   NaN
# 577   NaN
# 578   NaN
# 579   NaN
# Length: 580, dtype: float64

# %% [markdown]
# # the year-on-year change in boundary wall condition

# %%
ed['Year on Year Change'] = ed['Boundary wall'].diff()
print("Year-on-year change in boundary wall condition:")
print(['Year on Year Change'])
# Out:
# Year-on-year change in boundary wall condition:
# 0            NaN
# 1       9.704002
# 2     -17.313724
# 3      -4.762458
# 4       8.122142
#          ...
# 575    11.267582
# 576   -17.884807
# 577   -22.071156
# 578     8.518710
# 579     6.097993
# Name: Year on Year Change, Length: 580, dtype: float64
